# %% [markdown]
# <a href="https://colab.research.google.com/github/gilandher/Gilberto-Hoja-De-Vida/blob/main/IntroduccionGoogleColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(8))
print(type("Andres"))
print(type(9j +4))
print(type[2,2,4])
print(type({"hola",4,18,False}))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'complex'>
# type[2, 2, 4]
# <class 'set'>
